# %%
# %load_ext sql

# %%
import pandas as pd
from IPython.display import Image
import matplotlib 
from matplotlib import pyplot as plt

# %% [markdown]
# If necessary, change the following line to the correct filename. No quotation marks are needed!

# %%
# %sql sqlite:///Bank_post.sqlite

# %%
# %sql SELECT * FROM sqlite_master;
# Out:
#  * sqlite:///Bank_post.sqlite
# Done.
# [('table', 'customers', 'customers', 2, 'CREATE TABLE customers (\n\t"Age" BIGINT, \n\t"Experience" BIGINT, \n\t"Income" BIGINT, \n\t"BranchAddress" TEXT, \n\t"Branch Manager" TEXT, \n\t"Fam ... (325 characters truncated) ...  \n\t"Branch Manager 2" TEXT, \n\t"Branch Address 3" TEXT, \n\t"Branch Manager 3" TEXT, \n\t"Branch Address 4" FLOAT, \n\t"Branch Manager 4" FLOAT\n)')]

# %% [markdown]
# ### Let's remove some spaces in some column names:

# %%
# %sql ALTER TABLE customers RENAME COLUMN "Advisor Name" to AdvisorName;
# Out:
#  * sqlite:///Bank_post.sqlite
# (sqlite3.OperationalError) near "Name": syntax error
# [SQL: ALTER TABLE customers RENAME COLUMN Advisor Name to AdvisorName;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %sql ALTER TABLE customers RENAME COLUMN "Branch Address" to BranchAddress;
# Out:
#  * sqlite:///Bank_post.sqlite
# (sqlite3.OperationalError) near "Address": syntax error
# [SQL: ALTER TABLE customers RENAME COLUMN Branch Address to BranchAddress;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %sql ALTER TABLE customers RENAME COLUMN "Personal Loan" to PersonalLoan;
# Out:
#  * sqlite:///Bank_post.sqlite
# (sqlite3.OperationalError) near "Loan": syntax error
# [SQL: ALTER TABLE customers RENAME COLUMN Personal Loan to PersonalLoan;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# # A) Database design and SQL

# %% [markdown]
# i)	<b>What are the entities of the given scenario?</b>

# %% [markdown]
# Entities are things that exist. Several answers may have been posed, as long as they are consistent. <br>
# <br>
# Entity Customer, with attributes: age, experience, income, branch Address, Family, CCAvg, Mortgage, Personal Loan, Brokerage Account, GIC, Online, Credit Card, Advisor Name <br>
#
# Entity Branch, with attributes branch address, branch managers <br>
#
# Entity Advisor, with attributes: Advisor Name, Advisor Designation, Branch i, Branch Manager i

# %% [markdown]
# ii)	<b>This data set is not in Boyce-Codd Normal Form (BCNF). Explain why not.</b>

# %% [markdown]
# A BCNF dataset is a relation in its third normal form (3NF). To be 3NF, a dataset needs to be in its first normal form, second normal form, with its only determinants are candidate keys. A determinant is an attribute (or collection) that functionally determines another attribute.
#
# Let's analyze:
#
# The dataset is in 1NF: there are not repeating groups (for example, stacked branch and branch manager i in a single cell would not be 1NF)
#
# The dataset is in 2NF: All non key attributes are dependent on some of the primary keys (which we'll define as the entities)
#
# The dataset is not in 3NF: A dataset is in 3NF if the only determinants it contains are candidate keys. A candidate key (unique identifiers for a table). <br>
# In our case, you can see that <br>
# a) 'Advisor Name' keeps repeating for many different customers. Meaning that branch manager i and branch address i could be determined by advisor name, which should be a primary key <br>
# b) 'Branch Manager' and  keeps also repeating, meaning that it could be determiend by a branch unique id/Address

# %% [markdown]
# <b> iii) Transform the given data set into a database in BCNF. Draw an Entity-Relationship diagram of your resulting database</b>

# %%
# MANY customers share ONE advisor
# MANY adsvisors serve MANY branches
# ONE Branch has MANY customers

# %%
# With "ids" being created
Image(filename='diagram_post.png', width=500)

# %% [markdown]
# <b>iv)	Write SQL code that creates the necessary table(s) within the database. </b><br>
# #Customer:
# CREATE TABLE customer( age experience branch_id family CCAvg mortgage personal_loan brokerage_account GIC_account online credit_card adv_id .....

# %% [markdown]
# <b> v)	… all financial advisors.</b>

# %%
# %sql SELECT distinct AdvisorName FROM customers order by AdvisorName asc;
# Out:
#  * sqlite:///Bank_post.sqlite
# Done.
# [('Aleida Suitt',),
#  ('Beatriz Rolf',),
#  ('Bernarda Guilliams',),
#  ('Berry Gartman',),
#  ('Brandon Sum',),
#  ('Caitlin Wimmer',),
#  ('Carolin Whitmire',),
#  ('Carylon Race',),
#  ('Cecil Caves',),
#  ('Collene Dubon',),
#  ('Corazon Eastin',),
#  ('Cyndy Calcagno',),
#  ('Cyril Murry',),
#  ('Deedra Halderman',),
#  ('Donetta Mallet',),
#  ('Elicia Schuyler',),
#  ('Erik Clinard',),
#  ('Estefana Dungan',),
#  ('Eulah Kicklighter',),
#  ('Gala Mackson',),
#  ('Gita Pinelli',),
#  ('Jacqueline Leveque',),
#  ('Jaquelyn Cubbage',),
#  ('Jodie Izquierdo',),
#  ('Kathaleen Horgan',),
#  ('Kirsten Mitchem',),
#  ('Kristle Hanby',),
#  ('Latrisha Barden',),
#  ('Marcelene Thomson',),
#  ('Margret Lan',),
#  ('Mariana Ghent',),
#  ('Marylee Bristow',),
#  ('Myesha Bromley',),
#  ('Pansy Diblasi',),
#  ('Pete Dickens',),
#  ('Prudence Masters',),
#  ('Ross Seipel',),
#  ('Siobhan Flaugher',),
#  ('Tanya Johansen',),
#  ('Taylor Kemp',),
#  ('Thao Lovato',),
#  ('Twila Bare',),
#  ('Val Sauceda',),
#  ('Vicki Sowers',),
#  ('Weston Jeon',),
#  ('Ying Michaelson',),
#  ('Zandra Venne',),
#  ('Zetta Gephart',),
#  ('Zofia Rambo',)]

# %% [markdown]
# <b> vi)	… Age, Experience, Income and Mortgage of customers who have a mortgage.</b>

# %%
# %sql SELECT age, Experience, Income, Mortgage FROM customers where Mortgage <> 0 order by Mortgage asc;
# Out:
#  * sqlite:///Bank_post.sqlite
# Done.
# [(63, 38, 22, '$90'),
#  (38, 12, 91, '100'),
#  (63, 39, 32, '100'),
#  (30, 6, 42, '100'),
#  (43, 16, 65, '100'),
#  (61, 36, 40, '100'),
#  (32, 6, 85, '100'),
#  (63, 38, 9, '100'),
#  (36, 11, 14, '100'),
#  (53, 26, 22, '100'),
#  (45, 18, 10, '100'),
#  (38, 14, 28, '100'),
#  (51, 25, 92, '100'),
#  (40, 14, 42, '101'),
#  (50, 23, 15, '101'),
#  (49, 24, 13, '101'),
#  (36, 9, 44, '101'),
#  (39, 14, 21, '101'),
#  (55, 31, 34, '101'),
#  (44, 20, 93, '101'),
#  (52, 27, 15, '101'),
#  (31, 5, 115, '101'),
#  (38, 14, 25, '101'),
#  (60, 34, 33, '101'),
#  (35, 9, 45, '101'),
#  (54, 29, 28, '101'),
#  (45, 19, 25, '102'),
#  (40, 15, 10, '102'),
#  (43, 19, 75, '102'),
#  (63, 37, 11, '102'),
#  (56, 30, 15, '102'),
#  (47, 23, 12, '102'),
#  (33, 8, 175, '102'),
#  (51, 25, 29, '102'),
#  (32, 8, 20, '102'),
#  (28, 2, 84, '102'),
#  (28, 4, 43, '102'),
#  (41, 17, 53, '102'),
#  (32, 2, 69, '102'),
#  (32, 8, 42, '102'),
#  (57, 31, 51, '103'),
#  (51, 26, 14, '103'),
#  (32, 8, 32, '103'),
#  (61, 36, 23, '103'),
#  (58, 34, 92, '103'),
#  (60, 34, 60, '103'),
#  (35, 5, 22, '103'),
#  (63, 39, 49, '103'),
#  (57, 31, 25, '103'),
#  (28, 4, 82, '103'),
#  (30, 5, 109, '103'),
#  (43, 17, 49, '103'),
#  (50, 25, 19, '103'),
#  (47, 23, 11, '103'),
#  (59, 33, 49, '104'),
#  (42, 18, 34, '104'),
#  (37, 13, 79, '104'),
#  (59, 34, 18, '104'),
#  (47, 21, 22, '104'),
#  (53, 27, 31, '104'),
#  (31, 6, 19, '104'),
#  (34, 8, 31, '104'),
#  (41, 17, 33, '104'),
#  (46, 20, 74, '104'),
#  (31, 5, 84, '105'),
#  (41, 15, 41, '105'),
#  (41, 16, 19, '105'),
#  (33, 9, 14, '105'),
#  (56, 31, 61, '105'),
#  (45, 21, 29, '105'),
#  (45, 15, 32, '105'),
#  (42, 18, 49, '106'),
#  (53, 28, 19, '106'),
#  (48, 22, 19, '106'),
#  (45, 21, 11, '106'),
#  (42, 18, 71, '106'),
#  (34, 8, 20, '106'),
#  (63, 37, 90, '106'),
#  (49, 25, 13, '106'),
#  (33, 7, 139, '106'),
#  (40, 14, 42, '106'),
#  (31, 6, 83, '106'),
#  (61, 36, 169, '106'),
#  (40, 15, 40, '107'),
#  (52, 28, 44, '107'),
#  (59, 35, 14, '107'),
#  (47, 21, 93, '107'),
#  (51, 27, 155, '107'),
#  (39, 14, 85, '107'),
#  (32, 7, 35, '108'),
#  (45, 21, 33, '108'),
#  (39, 14, 54, '108'),
#  (39, 13, 41, '108'),
#  (39, 14, 28, '108'),
#  (64, 39, 38, '108'),
#  (33, 9, 41, '108'),
#  (57, 32, 55, '108'),
#  (32, 2, 71, '108'),
#  (60, 36, 14, '109'),
#  (53, 28, 18, '109'),
#  (56, 30, 31, '109'),
#  (31, 4, 54, '109'),
#  (50, 24, 32, '109'),
#  (51, 26, 12, '109'),
#  (56, 31, 65, '109'),
#  (63, 39, 49, '109'),
#  (30, 5, 22, '109'),
#  (54, 29, 25, '109'),
#  (27, 0, 40, '110'),
#  (35, 9, 51, '110'),
#  (50, 25, 42, '110'),
#  (29, 4, 22, '110'),
#  (56, 26, 38, '110'),
#  (43, 18, 85, '110'),
#  (58, 33, 18, '110'),
#  (46, 21, 44, '110'),
#  (63, 38, 159, '111'),
#  (32, 8, 14, '111'),
#  (62, 37, 22, '111'),
#  (56, 31, 25, '111'),
#  (34, 10, 34, '111'),
#  (27, 3, 40, '111'),
#  (53, 29, 120, '111'),
#  (49, 25, 20, '111'),
#  (26, 2, 30, '111'),
#  (43, 18, 83, '112'),
#  (60, 34, 23, '112'),
#  (45, 18, 53, '112'),
#  (50, 26, 22, '112'),
#  (32, 5, 41, '112'),
#  (48, 22, 43, '112'),
#  (27, 0, 34, '112'),
#  (52, 28, 118, '112'),
#  (61, 35, 50, '112'),
#  (29, 2, 30, '112'),
#  (47, 21, 125, '112'),
#  (46, 21, 30, '112'),
#  (27, 1, 74, '112'),
#  (58, 34, 68, '113'),
#  (40, 15, 52, '113'),
#  (62, 37, 39, '113'),
#  (54, 27, 51, '113'),
#  (45, 18, 48, '113'),
#  (57, 32, 21, '113'),
#  (26, 1, 55, '113'),
#  (56, 29, 45, '113'),
#  (37, 11, 14, '113'),
#  (65, 39, 25, '113'),
#  (41, 11, 35, '114'),
#  (56, 31, 35, '114'),
#  (31, 6, 53, '114'),
#  (52, 27, 34, '114'),
#  (37, 11, 22, '114'),
#  (36, 11, 158, '114'),
#  (51, 26, 15, '114'),
#  (33, 9, 14, '114'),
#  (64, 40, 15, '115'),
#  (33, 9, 38, '115'),
#  (63, 37, 15, '115'),
#  (34, 8, 39, '115'),
#  (43, 18, 60, '115'),
#  (58, 28, 122, '115'),
#  (59, 35, 102, '115'),
#  (47, 22, 30, '115'),
#  (35, 10, 21, '115'),
#  (63, 37, 42, '115'),
#  (54, 29, 70, '116'),
#  (31, 6, 81, '116'),
#  (64, 39, 42, '116'),
#  (40, 10, 19, '116'),
#  (39, 9, 32, '116'),
#  (62, 38, 24, '116'),
#  (39, 15, 24, '116'),
#  (46, 21, 40, '116'),
#  (37, 13, 38, '116'),
#  (52, 28, 163, '116'),
#  (26, 2, 20, '116'),
#  (32, 7, 35, '116'),
#  (30, 5, 20, '117'),
#  (30, 6, 64, '117'),
#  (30, 6, 29, '117'),
#  (51, 25, 68, '117'),
#  (42, 16, 20, '117'),
#  (57, 32, 21, '117'),
#  (63, 39, 40, '118'),
#  (62, 38, 35, '118'),
#  (53, 28, 85, '118'),
#  (52, 28, 168, '118'),
#  (27, 3, 119, '118'),
#  (50, 26, 19, '118'),
#  (60, 36, 30, '118'),
#  (55, 30, 35, '118'),
#  (41, 16, 23, '118'),
#  (62, 36, 63, '118'),
#  (51, 27, 62, '118'),
#  (29, 5, 21, '119'),
#  (36, 11, 15, '119'),
#  (51, 26, 62, '119'),
#  (53, 28, 55, '119'),
#  (55, 29, 64, '119'),
#  (58, 32, 145, '119'),
#  (26, 1, 61, '119'),
#  (40, 15, 18, '119'),
#  (26, 1, 35, '119'),
#  (27, 2, 48, '119'),
#  (65, 40, 34, '119'),
#  (58, 32, 113, '119'),
#  (33, 6, 78, '119'),
#  (44, 20, 39, '119'),
#  (54, 30, 120, '119'),
#  (38, 13, 19, '120'),
#  (52, 28, 18, '120'),
#  (57, 31, 53, '120'),
#  (50, 25, 38, '120'),
#  (32, 8, 142, '120'),
#  (43, 19, 35, '120'),
#  (27, 2, 103, '120'),
#  (50, 24, 79, '120'),
#  (59, 35, 21, '120'),
#  (65, 39, 94, '120'),
#  (65, 41, 134, '121'),
#  (52, 28, 52, '121'),
#  (52, 27, 45, '121'),
#  (34, 10, 88, '121'),
#  (49, 24, 18, '121'),
#  (38, 13, 84, '121'),
#  (55, 29, 19, '121'),
#  (30, 4, 23, '121'),
#  (48, 22, 42, '121'),
#  (26, 0, 19, '121'),
#  (31, 4, 29, '121'),
#  (33, 6, 54, '122'),
#  (64, 40, 169, '122'),
#  (34, 9, 195, '122'),
#  (31, 6, 44, '122'),
#  (54, 30, 88, '122'),
#  (48, 23, 23, '122'),
#  (59, 35, 35, '122'),
#  (45, 20, 191, '123'),
#  (58, 34, 25, '123'),
#  (51, 26, 43, '123'),
#  (26, 1, 24, '123'),
#  (60, 35, 22, '123'),
#  (58, 33, 51, '123'),
#  (62, 38, 64, '123'),
#  (28, 3, 51, '123'),
#  (61, 36, 21, '123'),
#  (62, 37, 19, '124'),
#  (35, 8, 38, '124'),
#  (31, 5, 18, '124'),
#  (34, 9, 72, '124'),
#  (36, 11, 31, '124'),
#  (63, 38, 31, '125'),
#  (35, 9, 21, '125'),
#  (49, 22, 82, '125'),
#  (37, 11, 35, '125'),
#  (56, 30, 75, '125'),
#  (46, 20, 25, '125'),
#  (44, 17, 22, '126'),
#  (35, 11, 68, '126'),
#  (35, 9, 29, '126'),
#  (40, 16, 42, '126'),
#  (31, 5, 91, '126'),
#  (31, 5, 65, '126'),
#  (56, 32, 23, '127'),
#  (62, 37, 18, '127'),
#  (39, 15, 61, '127'),
#  (33, 7, 29, '127'),
#  (59, 33, 100, '127'),
#  (37, 11, 71, '127'),
#  (59, 33, 68, '128'),
#  (46, 20, 73, '128'),
#  (61, 35, 40, '128'),
#  (62, 36, 42, '128'),
#  (62, 38, 30, '128'),
#  (54, 28, 49, '128'),
#  (46, 21, 41, '128'),
#  (50, 25, 21, '129'),
#  (39, 13, 40, '129'),
#  (61, 37, 54, '129'),
#  (60, 34, 21, '129'),
#  (30, 5, 38, '129'),
#  (36, 9, 40, '129'),
#  (30, 5, 98, '129'),
#  (46, 21, 38, '130'),
#  (29, 3, 154, '130'),
#  (31, 5, 32, '130'),
#  (43, 17, 53, '130'),
#  (34, 10, 51, '130'),
#  (36, 10, 28, '130'),
#  (31, 5, 29, '131'),
#  (40, 15, 51, '131'),
#  (56, 30, 39, '131'),
#  (31, 7, 35, '131'),
#  (59, 35, 33, '131'),
#  (39, 15, 62, '131'),
#  (50, 26, 40, '131'),
#  (35, 11, 85, '131'),
#  (28, 4, 58, '131'),
#  (51, 25, 45, '131'),
#  (41, 17, 92, '131'),
#  (34, 10, 42, '131'),
#  (58, 33, 23, '131'),
#  (53, 29, 20, '131'),
#  (53, 23, 45, '132'),
#  (42, 15, 39, '132'),
#  (45, 21, 158, '132'),
#  (45, 21, 140, '132'),
#  (26, 2, 60, '132'),
#  (54, 24, 69, '132'),
#  (33, 7, 30, '132'),
#  (42, 18, 145, '132'),
#  (54, 28, 93, '133'),
#  (33, 9, 38, '133'),
#  (30, 5, 73, '133'),
#  (49, 23, 84, '134'),
#  (38, 14, 130, '134'),
#  (57, 32, 59, '134'),
#  (24, 0, 88, '134'),
#  (64, 40, 90, '134'),
#  (33, 7, 73, '135'),
#  (28, 3, 29, '135'),
#  (42, 16, 55, '135'),
#  (52, 25, 44, '135'),
#  (59, 35, 40, '135'),
#  (30, 6, 25, '135'),
#  (61, 35, 28, '135'),
#  (41, 16, 35, '135'),
#  (47, 21, 120, '135'),
#  (53, 27, 35, '136'),
#  (34, 8, 85, '136'),
#  (35, 11, 38, '136'),
#  (45, 21, 33, '136'),
#  (56, 32, 25, '136'),
#  (42, 18, 43, '136'),
#  (29, 3, 39, '137'),
#  (56, 31, 21, '137'),
#  (57, 31, 40, '137'),
#  (35, 11, 32, '137'),
#  (31, 6, 170, '137'),
#  (62, 37, 21, '137'),
#  (50, 25, 24, '137'),
#  (34, 8, 35, '137'),
#  (64, 38, 42, '137'),
#  (35, 9, 82, '138'),
#  (54, 24, 63, '138'),
#  (49, 25, 24, '138'),
#  (38, 12, 45, '138'),
#  (65, 40, 95, '138'),
#  (47, 22, 81, '138'),
#  (56, 31, 28, '138'),
#  (66, 40, 42, '138'),
#  (64, 39, 59, '139'),
#  (51, 26, 59, '139'),
#  (30, 4, 102, '139'),
#  (60, 36, 39, '140'),
#  (38, 13, 129, '140'),
#  (48, 22, 145, '140'),
#  (28, 3, 25, '140'),
#  (57, 32, 24, '140'),
#  (51, 25, 29, '140'),
#  (33, 9, 73, '140'),
#  (63, 37, 32, '141'),
#  (52, 28, 31, '141'),
#  (33, 7, 54, '141'),
#  (51, 27, 44, '141'),
#  (44, 20, 33, '142'),
#  (62, 32, 53, '142'),
#  (54, 29, 48, '142'),
#  (61, 35, 25, '142'),
#  (34, 10, 43, '142'),
#  (49, 23, 60, '142'),
#  (30, 6, 179, '142'),
#  (47, 22, 24, '142'),
#  (57, 27, 64, '142'),
#  (30, 6, 31, '142'),
#  (30, 4, 44, '143'),
#  (54, 28, 80, '143'),
#  (41, 17, 34, '143'),
#  (31, 5, 180, '144'),
#  (54, 29, 72, '144'),
#  (53, 29, 33, '144'),
#  (57, 32, 80, '144'),
#  (50, 26, 85, '144'),
#  (53, 27, 38, '144'),
#  (39, 14, 74, '144'),
#  (55, 25, 35, '144'),
#  (43, 18, 38, '144'),
#  (51, 25, 30, '144'),
#  (45, 20, 38, '144'),
#  (23, -3, 55, '145'),
#  (57, 31, 30, '145'),
#  (37, 11, 81, '145'),
#  (48, 24, 71, '145'),
#  (48, 22, 84, '145'),
#  (36, 12, 62, '145'),
#  (65, 41, 91, '146'),
#  (46, 20, 134, '146'),
#  (58, 33, 28, '146'),
#  (53, 27, 89, '146'),
#  (30, 6, 95, '146'),
#  (41, 16, 81, '146'),
#  (37, 11, 30, '146'),
#  (28, 3, 123, '146'),
#  (34, 9, 55, '147'),
#  (55, 29, 72, '147'),
#  (36, 12, 25, '147'),
#  (52, 28, 178, '147'),
#  (38, 12, 52, '147'),
#  (63, 39, 64, '147'),
#  (47, 22, 25, '148'),
#  (45, 21, 38, '148'),
#  (54, 24, 29, '148'),
#  (61, 36, 59, '148'),
#  (58, 32, 41, '148'),
#  (35, 11, 58, '149'),
#  (55, 30, 28, '149'),
#  (54, 29, 62, '149'),
#  (42, 16, 32, '149'),
#  (46, 22, 72, '149'),
#  (62, 38, 42, '149'),
#  (28, 3, 71, '149'),
#  (42, 16, 55, '149'),
#  (27, 1, 99, '149'),
#  (54, 28, 79, '150'),
#  (41, 14, 38, '150'),
#  (59, 33, 71, '150'),
#  (35, 11, 101, '150'),
#  (65, 39, 35, '150'),
#  (26, 1, 80, '150'),
#  (55, 29, 55, '151'),
#  (50, 26, 42, '151'),
#  (42, 18, 60, '151'),
#  (39, 15, 91, '151'),
#  (39, 9, 29, '151'),
#  (52, 28, 31, '151'),
#  (49, 23, 79, '151'),
#  (57, 33, 30, '151'),
#  (39, 15, 168, '152'),
#  (54, 29, 59, '152'),
#  (33, 7, 32, '152'),
#  (38, 14, 58, '153'),
#  (49, 23, 41, '153'),
#  (57, 33, 122, '153'),
#  (26, 0, 42, '153'),
#  (36, 11, 162, '153'),
#  (39, 14, 43, '153'),
#  (56, 32, 44, '153'),
#  (39, 13, 89, '153'),
#  (27, 1, 58, '154'),
#  (27, 0, 38, '154'),
#  (32, 6, 51, '154'),
#  (43, 18, 53, '154'),
#  (26, 0, 149, '154'),
#  (46, 20, 54, '154'),
#  (62, 36, 41, '154'),
#  (39, 13, 74, '155'),
#  (37, 13, 29, '155'),
#  (45, 21, 59, '155'),
#  (34, 9, 99, '155'),
#  (43, 19, 31, '156'),
#  (31, 5, 34, '156'),
#  (47, 23, 32, '156'),
#  (47, 23, 40, '156'),
#  (34, 10, 131, '156'),
#  (29, 3, 30, '157'),
#  (27, 1, 78, '157'),
#  (55, 30, 34, '157'),
#  (49, 24, 30, '157'),
#  (48, 23, 132, '157'),
#  (57, 32, 44, '157'),
#  (31, 5, 85, '157'),
#  (40, 16, 32, '158'),
#  (42, 18, 144, '158'),
#  (55, 25, 92, '158'),
#  (30, 5, 30, '158'),
#  (29, 3, 45, '158'),
#  (38, 12, 180, '158'),
#  (27, 3, 201, '158'),
#  (58, 32, 42, '158'),
#  (42, 18, 43, '158'),
#  (52, 27, 29, '159'),
#  (39, 14, 54, '159'),
#  (46, 22, 118, '159'),
#  (63, 37, 30, '159'),
#  (45, 19, 60, '159'),
#  (36, 11, 152, '159'),
#  (48, 23, 43, '159'),
#  (59, 35, 161, '160'),
#  (29, 2, 33, '160'),
#  (49, 24, 75, '160'),
#  (28, 3, 118, '161'),
#  (43, 16, 78, '161'),
#  (29, 5, 31, '161'),
#  (58, 32, 85, '161'),
#  (28, 2, 41, '161'),
#  (50, 24, 30, '161'),
#  (34, 9, 41, '161'),
#  (57, 33, 93, '161'),
#  (65, 40, 128, '162'),
#  (39, 13, 71, '162'),
#  (48, 23, 30, '162'),
#  (28, 1, 34, '162'),
#  (49, 24, 68, '163'),
#  (44, 18, 43, '163'),
#  (47, 22, 122, '163'),
#  (36, 6, 78, '163'),
#  (51, 27, 38, '164'),
#  (45, 20, 55, '164'),
#  (34, 10, 34, '164'),
#  (42, 17, 54, '164'),
#  (35, 10, 48, '164'),
#  (33, 8, 64, '164'),
#  (34, 9, 134, '164'),
#  (60, 36, 32, '165'),
#  (52, 25, 43, '165'),
#  (36, 12, 70, '165'),
#  (60, 34, 40, '166'),
#  (63, 39, 50, '166'),
#  (56, 32, 38, '166'),
#  (57, 32, 43, '166'),
#  (36, 11, 40, '166'),
#  (31, 7, 43, '166'),
#  (49, 22, 103, '167'),
#  (61, 35, 53, '167'),
#  (49, 19, 169, '167'),
#  (63, 37, 40, '167'),
#  (52, 26, 121, '167'),
#  (28, 2, 33, '167'),
#  (32, 6, 54, '167'),
#  (50, 24, 32, '167'),
#  (47, 22, 61, '168'),
#  (57, 33, 43, '168'),
#  (58, 34, 55, '168'),
#  (51, 26, 70, '169'),
#  (26, 1, 48, '169'),
#  (38, 14, 48, '169'),
#  (58, 34, 58, '169'),
#  (60, 35, 35, '169'),
#  (54, 27, 43, '169'),
#  (39, 13, 58, '169'),
#  (31, 5, 40, '170'),
#  (28, 4, 69, '170'),
#  (28, 3, 120, '170'),
#  (63, 37, 124, '170'),
#  (42, 16, 62, '170'),
#  (60, 35, 44, '170'),
#  (31, 5, 101, '170'),
#  (31, 5, 35, '171'),
#  (32, 7, 98, '171'),
#  (44, 14, 33, '171'),
#  (55, 29, 81, '171'),
#  (59, 33, 35, '171'),
#  (41, 17, 45, '172'),
#  (30, 4, 51, '172'),
#  (45, 20, 62, '172'),
#  (66, 42, 35, '172'),
#  (56, 30, 44, '174'),
#  (65, 40, 115, '174'),
#  (38, 12, 39, '174'),
#  (35, 10, 94, '174'),
#  (59, 33, 41, '174'),
#  (59, 35, 53, '174'),
#  (40, 16, 50, '174'),
#  (32, 8, 98, '175'),
#  (60, 35, 43, '175'),
#  (27, 1, 140, '175'),
#  (26, 1, 55, '175'),
#  (65, 39, 184, '176'),
#  (39, 15, 41, '176'),
#  (58, 34, 41, '177'),
#  (57, 31, 58, '177'),
#  (63, 39, 38, '178'),
#  (27, 2, 92, '178'),
#  (52, 28, 72, '178'),
#  (61, 36, 54, '179'),
#  (32, 6, 41, '179'),
#  (64, 38, 79, '179'),
#  (43, 19, 71, '179'),
#  (44, 14, 44, '180'),
#  (43, 18, 103, '180'),
#  (41, 17, 38, '180'),
#  (45, 20, 84, '180'),
#  (49, 25, 53, '181'),
#  (37, 11, 60, '181'),
#  (57, 33, 45, '181'),
#  (46, 21, 205, '181'),
#  (42, 18, 110, '182'),
#  (51, 27, 39, '182'),
#  (61, 36, 60, '182'),
#  (67, 42, 75, '182'),
#  (31, 7, 38, '182'),
#  (52, 26, 79, '183'),
#  (63, 38, 135, '183'),
#  (44, 20, 69, '184'),
#  (50, 24, 188, '184'),
#  (42, 18, 89, '184'),
#  (64, 38, 63, '184'),
#  (57, 32, 68, '184'),
#  (62, 37, 169, '184'),
#  (36, 12, 92, '184'),
#  (45, 21, 39, '184'),
#  (29, 4, 62, '184'),
#  (30, 5, 42, '184'),
#  (47, 21, 79, '185'),
#  (47, 20, 79, '185'),
#  (54, 30, 54, '185'),
#  (31, 6, 55, '185'),
#  (40, 14, 70, '185'),
#  (41, 17, 42, '185'),
#  (64, 40, 92, '185'),
#  (64, 39, 73, '185'),
#  (61, 35, 49, '185'),
#  (31, 5, 39, '185'),
#  (37, 11, 71, '185'),
#  (48, 24, 54, '186'),
#  (56, 32, 120, '186'),
#  (64, 38, 38, '186'),
#  (62, 37, 83, '187'),
#  (33, 7, 81, '187'),
#  (54, 29, 44, '187'),
#  (40, 14, 42, '187'),
#  (46, 22, 53, '187'),
#  (54, 28, 94, '188'),
#  (50, 25, 83, '188'),
#  (30, 6, 69, '188'),
#  (36, 12, 73, '188'),
#  (31, 5, 115, '189'),
#  (46, 20, 54, '189'),
#  (61, 36, 50, '189'),
#  (46, 20, 64, '189'),
#  (63, 39, 72, '190'),
#  (55, 29, 78, '190'),
#  (38, 13, 63, '190'),
#  (57, 32, 68, '191'),
#  (27, 2, 130, '192'),
#  (32, 8, 44, '192'),
#  (50, 25, 44, '192'),
#  (37, 13, 49, '192'),
#  (60, 34, 44, '192'),
#  (35, 8, 44, '192'),
#  (58, 33, 61, '193'),
#  (53, 28, 41, '193'),
#  (48, 22, 150, '193'),
#  (53, 27, 81, '193'),
#  (58, 33, 142, '193'),
#  (45, 18, 44, '193'),
#  (56, 30, 61, '193'),
#  (47, 21, 52, '194'),
#  (40, 14, 78, '194'),
#  (46, 21, 99, '194'),
#  (61, 35, 79, '194'),
#  (58, 32, 191, '194'),
#  (34, 9, 75, '194'),
#  (49, 25, 44, '194'),
#  (57, 33, 45, '195'),
#  (65, 39, 150, '196'),
#  (30, 6, 49, '196'),
#  (44, 20, 52, '196'),
#  (39, 14, 128, '196'),
#  (38, 13, 54, '196'),
#  (40, 16, 120, '196'),
#  (55, 30, 42, '196'),
#  (26, 1, 190, '197'),
#  (51, 27, 55, '197'),
#  (57, 33, 134, '198'),
#  (57, 31, 45, '198'),
#  (53, 23, 44, '198'),
#  (51, 25, 71, '198'),
#  (59, 34, 145, '198'),
#  (42, 17, 91, '199'),
#  (26, 2, 82, '199'),
#  (39, 13, 59, '199'),
#  (30, 4, 83, '199'),
#  (28, 3, 115, '200'),
#  (44, 20, 50, '200'),
#  (64, 39, 85, '200'),
#  (62, 37, 45, '200'),
#  (58, 34, 45, '201'),
#  (44, 20, 82, '201'),
#  (44, 18, 54, '202'),
#  (62, 36, 115, '202'),
#  (27, 2, 68, '203'),
#  (48, 22, 85, '203'),
#  (42, 17, 72, '203'),
#  (61, 36, 193, '203'),
#  (40, 16, 45, '204'),
#  (29, 4, 134, '204'),
#  (60, 36, 49, '204'),
#  (36, 10, 78, '204'),
#  (52, 26, 110, '204'),
#  (57, 33, 45, '204'),
#  (25, 1, 74, '204'),
#  (63, 37, 191, '205'),
#  (63, 38, 50, '205'),
#  (54, 30, 45, '205'),
#  (36, 12, 64, '205'),
#  (32, 7, 61, '205'),
#  (49, 23, 78, '205'),
#  (38, 13, 81, '206'),
#  (30, 4, 154, '207'),
#  (55, 25, 52, '207'),
#  (33, 7, 48, '207'),
#  (44, 20, 71, '207'),
#  (30, 6, 72, '207'),
#  (52, 27, 61, '207'),
#  (63, 38, 111, '207'),
#  (34, 8, 81, '208'),
#  (51, 25, 119, '208'),
#  (57, 31, 64, '208'),
#  (29, 5, 128, '209'),
#  (46, 22, 69, '209'),
#  (41, 17, 143, '209'),
#  (55, 29, 81, '209'),
#  (31, 5, 50, '209'),
#  (45, 20, 144, '210'),
#  (37, 12, 194, '211'),
#  (52, 28, 64, '211'),
#  (41, 16, 113, '211'),
#  (49, 24, 79, '212'),
#  (50, 24, 161, '212'),
#  (29, 5, 133, '212'),
#  (33, 8, 48, '212'),
#  (46, 22, 135, '213'),
#  (47, 22, 53, '213'),
#  (50, 26, 92, '213'),
#  (57, 33, 49, '214'),
#  (33, 6, 49, '214'),
#  (36, 12, 51, '214'),
#  (67, 43, 79, '215'),
#  (41, 17, 48, '215'),
#  (55, 30, 55, '215'),
#  (40, 16, 89, '216'),
#  (36, 12, 59, '216'),
#  (46, 22, 73, '216'),
#  (58, 32, 62, '217'),
#  (37, 12, 60, '217'),
#  (34, 8, 99, '217'),
#  (53, 29, 90, '217'),
#  (49, 23, 70, '217'),
#  (43, 19, 81, '218'),
#  (63, 38, 52, '218'),
#  (25, 1, 70, '218'),
#  (41, 17, 93, '218'),
#  (38, 14, 54, '218'),
#  (30, 6, 80, '219'),
#  (55, 25, 58, '219'),
#  (55, 31, 73, '219'),
#  (39, 15, 79, '219'),
#  (57, 31, 55, '219'),
#  (55, 29, 49, '220'),
#  (60, 35, 65, '220'),
#  (64, 38, 59, '220'),
#  (30, 5, 98, '220'),
#  (45, 19, 69, '220'),
#  (32, 7, 82, '221'),
#  (38, 13, 119, '221'),
#  (40, 14, 63, '221'),
#  (43, 17, 64, '221'),
#  (43, 19, 130, '221'),
#  (46, 22, 52, '221'),
#  (55, 29, 94, '221'),
#  (28, 3, 74, '221'),
#  (58, 32, 65, '222'),
#  (28, 3, 173, '222'),
#  (41, 17, 81, '223'),
#  (51, 25, 58, '223'),
#  (52, 22, 58, '223'),
#  (58, 32, 73, '224'),
#  (34, 9, 64, '224'),
#  (39, 13, 75, '224'),
#  (56, 31, 81, '225'),
#  (41, 16, 79, '225'),
#  (59, 33, 72, '226'),
#  (64, 40, 52, '226'),
#  (34, 8, 65, '227'),
#  (54, 30, 64, '227'),
#  (52, 28, 55, '227'),
#  (44, 20, 81, '228'),
#  (62, 38, 58, '228'),
#  (46, 21, 52, '228'),
#  (41, 17, 85, '229'),
#  (35, 10, 182, '229'),
#  (60, 34, 61, '229'),
#  (63, 39, 131, '229'),
#  (50, 24, 112, '229'),
#  (48, 24, 61, '229'),
#  (25, 1, 62, '229'),
#  (44, 19, 70, '230'),
#  (65, 41, 105, '230'),
#  (30, 6, 181, '230'),
#  (26, 1, 54, '230'),
#  (28, 3, 52, '230'),
#  (60, 34, 59, '231'),
#  (43, 19, 174, '231'),
#  (48, 23, 191, '231'),
#  (52, 28, 62, '231'),
#  (35, 10, 58, '232'),
#  (29, 4, 59, '232'),
#  (37, 7, 94, '232'),
#  (49, 23, 65, '232'),
#  (33, 7, 101, '233'),
#  (41, 16, 79, '233'),
#  (56, 30, 164, '234'),
#  (59, 34, 60, '234'),
#  (30, 4, 54, '235'),
#  (33, 3, 71, '236'),
#  (28, 4, 94, '236'),
#  (30, 4, 78, '236'),
#  (51, 26, 55, '236'),
#  (57, 32, 75, '236'),
#  (60, 34, 64, '236'),
#  (65, 39, 160, '237'),
#  (24, -2, 80, '238'),
#  (50, 25, 192, '238'),
#  (52, 26, 59, '239'),
#  (23, -1, 61, '239'),
#  (44, 20, 119, '239'),
#  (41, 15, 95, '240'),
#  (50, 26, 190, '240'),
#  (28, 3, 70, '240'),
#  (35, 11, 65, '240'),
#  (32, 7, 82, '240'),
#  (56, 32, 58, '241'),
#  (48, 22, 59, '241'),
#  (25, -1, 112, '241'),
#  (39, 14, 104, '242'),
#  (39, 13, 63, '242'),
#  (31, 5, 72, '242'),
#  (64, 40, 88, '243'),
#  (38, 13, 173, '243'),
#  (63, 37, 105, '244'),
#  (31, 1, 60, '244'),
#  (29, 3, 65, '244'),
#  (42, 18, 90, '245'),
#  (45, 21, 63, '245'),
#  (39, 9, 118, '246'),
#  (29, 3, 190, '246'),
#  (65, 40, 83, '247'),
#  (39, 13, 69, '247'),
#  (39, 13, 58, '247'),
#  (42, 16, 64, '247'),
#  (50, 24, 81, '248'),
#  (48, 22, 83, '248'),
#  (60, 34, 64, '248'),
#  (38, 14, 92, '249'),
#  (60, 34, 83, '249'),
#  (37, 12, 169, '249'),
#  (40, 16, 104, '249'),
#  (32, 6, 99, '249'),
#  (30, 6, 160, '249'),
#  (45, 19, 60, '250'),
#  (43, 18, 59, '250'),
#  (30, 5, 61, '251'),
#  (52, 26, 158, '251'),
#  (54, 30, 70, '251'),
#  (45, 18, 81, '251'),
#  (42, 16, 111, '251'),
#  (34, 8, 82, '251'),
#  (40, 14, 73, '252'),
#  (65, 39, 82, '252'),
#  (37, 12, 123, '253'),
#  (38, 14, 62, '255'),
#  (61, 35, 99, '255'),
#  (46, 20, 131, '256'),
#  (25, -1, 101, '256'),
#  (53, 29, 93, '256'),
#  (42, 16, 65, '256'),
#  (54, 28, 155, '256'),
#  (61, 36, 130, '257'),
#  (32, 8, 74, '257'),
#  (34, 10, 71, '257'),
#  (38, 14, 90, '258'),
#  (30, 4, 81, '259'),
#  (35, 9, 188, '259'),
#  (29, 5, 62, '260'),
#  (37, 11, 65, '260'),
#  (34, 9, 141, '260'),
#  (59, 33, 140, '262'),
#  (50, 24, 95, '262'),
#  (58, 34, 82, '263'),
#  (49, 23, 65, '263'),
#  (59, 33, 110, '264'),
#  (46, 20, 73, '264'),
#  (55, 29, 99, '264'),
#  (54, 30, 70, '265'),
#  (35, 11, 190, '266'),
#  (50, 24, 124, '266'),
#  (49, 24, 82, '267'),
#  (38, 12, 93, '267'),
#  (31, 5, 99, '268'),
#  (32, 8, 65, '268'),
#  (44, 19, 78, '268'),
#  (28, 4, 101, '270'),
#  (47, 20, 101, '270'),
#  (58, 32, 113, '270'),
#  (43, 17, 72, '271'),
#  (26, 2, 205, '271'),
#  (50, 24, 94, '272'),
#  (40, 15, 71, '272'),
#  (32, 8, 169, '272'),
#  (56, 26, 70, '273'),
#  (55, 25, 95, '275'),
#  (42, 17, 98, '275'),
#  (52, 28, 81, '275'),
#  (47, 22, 82, '276'),
#  (28, 4, 81, '276'),
#  (42, 18, 158, '277'),
#  (44, 20, 81, '277'),
#  (59, 35, 88, '278'),
#  (41, 16, 75, '280'),
#  (37, 13, 79, '280'),
#  (49, 24, 130, '281'),
#  (65, 41, 105, '282'),
#  (35, 11, 188, '282'),
#  (64, 39, 172, '282'),
#  (33, 7, 115, '283'),
#  (47, 23, 171, '284'),
#  (38, 13, 80, '285'),
#  (61, 37, 73, '285'),
#  (35, 10, 72, '285'),
#  (49, 23, 114, '286'),
#  (29, 3, 92, '287'),
#  (43, 18, 85, '287'),
#  (43, 17, 84, '289'),
#  (36, 10, 91, '289'),
#  (36, 11, 133, '290'),
#  (56, 30, 140, '292'),
#  (41, 15, 89, '292'),
#  (52, 27, 81, '293'),
#  (30, 5, 85, '293'),
#  (63, 39, 101, '294'),
#  (54, 28, 82, '294'),
#  (53, 27, 145, '294'),
#  (57, 33, 79, '294'),
#  (27, 3, 110, '294'),
#  (36, 10, 172, '295'),
#  (41, 16, 98, '296'),
#  (52, 25, 180, '297'),
#  (43, 19, 84, '297'),
#  (39, 14, 75, '297'),
#  (58, 32, 111, '298'),
#  (65, 40, 89, '299'),
#  (54, 29, 85, '299'),
#  (50, 26, 192, '301'),
#  (39, 12, 108, '301'),
#  (32, 6, 120, '301'),
#  (44, 18, 162, '301'),
#  (26, 0, 164, '301'),
#  (29, 4, 102, '303'),
#  (53, 28, 184, '303'),
#  (55, 30, 84, '304'),
#  (59, 35, 108, '304'),
#  (51, 26, 78, '305'),
#  (47, 23, 190, '305'),
#  (23, -1, 149, '305'),
#  (61, 37, 158, '306'),
#  (32, 6, 98, '306'),
#  (27, 3, 81, '307'),
#  (43, 18, 89, '307'),
#  (55, 29, 132, '307'),
#  (27, 1, 134, '307'),
#  (50, 25, 79, '307'),
#  (44, 20, 132, '308'),
#  (52, 26, 109, '308'),
#  (48, 23, 168, '308'),
#  (47, 22, 93, '309'),
#  (40, 15, 82, '309'),
#  (48, 23, 161, '310'),
#  (27, 3, 94, '310'),
#  (62, 37, 92, '310'),
#  (50, 25, 130, '311'),
#  (51, 25, 175, '312'),
#  (31, 6, 81, '313'),
#  (53, 27, 93, '313'),
#  (37, 13, 89, '314'),
#  (25, -1, 109, '314'),
#  (35, 10, 83, '315'),
#  (46, 21, 159, '315'),
#  (31, 7, 113, '315'),
#  (43, 19, 170, '318'),
#  (40, 15, 149, '319'),
#  (25, 0, 88, '319'),
#  (31, 5, 129, '319'),
#  (35, 9, 84, '322'),
#  (60, 34, 95, '322'),
#  (47, 23, 90, '323'),
#  (25, 0, 99, '323'),
#  (34, 9, 84, '323'),
#  (43, 18, 113, '325'),
#  (54, 28, 170, '325'),
#  (57, 31, 113, '327'),
#  (41, 17, 94, '327'),
#  (43, 18, 85, '327'),
#  (40, 14, 93, '328'),
#  (45, 21, 151, '328'),
#  (51, 26, 133, '328'),
#  (29, 3, 175, '329'),
#  (46, 20, 111, '329'),
#  (59, 33, 91, '329'),
#  ...]

# %% [markdown]
# <b> vii)	… the number of all customers for each branch. </b>

# %%
# %sql SELECT BranchAddress, count(*) as num_customers FROM customers group by BranchAddress order by num_customers asc;
# Out:
#  * sqlite:///Bank_post.sqlite
# Done.
# [('890 W. Brickyard Dr.', 41),
#  ('14 Lakeshore Lane', 75),
#  ('8722 Richardson Street', 76),
#  ('544 Edgewood Drive', 80),
#  ('76 Mayfair St.', 82),
#  ('667 E. Hall St.', 83),
#  ('218 S. Westport Court', 85),
#  ('9587 SW. Jefferson Street', 85),
#  ('387 West Fifth Ave.', 86),
#  ('8573 Princeton Road', 87),
#  ('20 Bradford Ave.', 88),
#  ('69 Spruce Dr.', 89),
#  ('91 Lake Court', 89),
#  ('36 Kent Court', 90),
#  ('4 Country Drive', 91),
#  ('533 Hillcrest Street', 91),
#  ('7330 West Grand St.', 91),
#  ('7041 East Mammoth Drive', 92),
#  ('8017 Homestead Ave.', 93),
#  ('5 Maple Lane', 94),
#  ('518 Selby Ave.', 94),
#  ('8376 Euclid Lane', 95),
#  ('9670 Wilson Rd.', 96),
#  ('7919 Cedarwood Dr.', 97),
#  ('92 Ridgewood Dr.', 97),
#  ('9091 S. Bowman Street', 99),
#  ('8378 West Magnolia Street', 102),
#  ('336 Pin Oak Ave.', 105),
#  ('742 Bridle Street', 105),
#  ('177 Winchester Street', 107),
#  ('68 Sunbeam St.', 111),
#  ('36 South St.', 124),
#  ('33 Harrison Road', 126),
#  ('24 Trusel Court', 135),
#  ('40 E. Dunbar Ave.', 135),
#  ('9251 Old Vernon St.', 136),
#  ('597 Lawrence Street', 139),
#  ('8536 Country Club Dr.', 140),
#  ('1 Poplar St.', 143),
#  ('9929 Thompson Lane', 144),
#  ('94 Country Club St.', 150),
#  ('9834 East Pineknoll Ave.', 164),
#  ('234 Blue Spring Rd.', 167)]

# %% [markdown]
# <b> viii)	… the maximum of the average credit card spending over all customer that took a personal loan.</b>

# %%
# Assuming CCAvg is all numbers and it's properly ordeable
# %sql select CCAvg from customers where PersonalLoan <> 0 order by CCAvg desc limit 1;
# Out:
#  * sqlite:///Bank_post.sqlite
# Done.
# [('9.3',)]

# %%
# OR
# %sql select max(CCAVg) from (select CCAvg from customers where PersonalLoan <> 0);
# Out:
#  * sqlite:///Bank_post.sqlite
# Done.
# [('9.3',)]

# %% [markdown]
# <b> ix)	Only consider advisors whose number of customers is more than half of the overall average number of customers per advisor. List these advisors and the mean income of their customers combined in descending order (by mean income). </b>

# %%
# Subquery, not the answer.
#%%sql 
#SELECT AVG(numc) 
#FROM (select AdvisorName, count(*) as numc 
#      from customers group by AdvisorName);

# %%
# %%sql
# SELECT AdvisorName, count(*) as num_customers, avg(Income) as avgIncome
# from customers group by AdvisorName
# having num_customers > 0.5*(SELECT AVG(numc) from (select AdvisorName, count(*) as numc from customers group by AdvisorName))
# order by avgIncome desc;
# Out:
#  * sqlite:///Bank_post.sqlite
# Done.
# [('Zofia Rambo', 108, 84.99074074074075),
#  ('Pansy Diblasi', 87, 82.19540229885058),
#  ('Erik Clinard', 91, 82.05494505494505),
#  ('Kathaleen Horgan', 100, 81.75),
#  ('Kirsten Mitchem', 80, 80.8),
#  ('Jodie Izquierdo', 88, 80.43181818181819),
#  ('Corazon Eastin', 119, 80.41176470588235),
#  ('Donetta Mallet', 88, 79.5909090909091),
#  ('Kristle Hanby', 100, 79.36),
#  ('Pete Dickens', 84, 79.27380952380952),
#  ('Margret Lan', 85, 79.21176470588236),
#  ('Cyril Murry', 80, 78.7625),
#  ('Marylee Bristow', 84, 77.9047619047619),
#  ('Jacqueline Leveque', 98, 77.76530612244898),
#  ('Elicia Schuyler', 109, 77.6788990825688),
#  ('Cecil Caves', 79, 76.50632911392405),
#  ('Latrisha Barden', 105, 76.0),
#  ('Marcelene Thomson', 82, 75.8048780487805),
#  ('Carylon Race', 95, 75.6842105263158),
#  ('Gita Pinelli', 86, 75.46511627906976),
#  ('Brandon Sum', 84, 75.41666666666667),
#  ('Mariana Ghent', 86, 74.67441860465117),
#  ('Taylor Kemp', 77, 74.49350649350649),
#  ('Bernarda Guilliams', 87, 74.4367816091954),
#  ('Estefana Dungan', 107, 74.05607476635514),
#  ('Collene Dubon', 93, 73.48387096774194),
#  ('Zetta Gephart', 82, 73.28048780487805),
#  ('Berry Gartman', 88, 73.18181818181819),
#  ('Tanya Johansen', 99, 73.07070707070707),
#  ('Vicki Sowers', 62, 72.8225806451613),
#  ('Siobhan Flaugher', 71, 72.77464788732394),
#  ('Carolin Whitmire', 99, 72.67676767676768),
#  ('Ross Seipel', 97, 72.62886597938144),
#  ('Cyndy Calcagno', 106, 72.5377358490566),
#  ('Jaquelyn Cubbage', 97, 72.12371134020619),
#  ('Aleida Suitt', 100, 71.64),
#  ('Myesha Bromley', 87, 71.51724137931035),
#  ('Beatriz Rolf', 102, 71.25490196078431),
#  ('Gala Mackson', 99, 71.16161616161617),
#  ('Deedra Halderman', 98, 70.96938775510205),
#  ('Thao Lovato', 94, 69.2127659574468),
#  ('Val Sauceda', 77, 68.96103896103897),
#  ('Prudence Masters', 93, 67.97849462365592),
#  ('Ying Michaelson', 77, 67.49350649350649),
#  ('Zandra Venne', 95, 67.18947368421053),
#  ('Caitlin Wimmer', 113, 66.61946902654867),
#  ('Eulah Kicklighter', 102, 65.12745098039215),
#  ('Weston Jeon', 98, 64.78571428571429),
#  ('Twila Bare', 81, 63.135802469135804)]

# %% [markdown]
# # B)	(8 points) Data Cleaning and Basic Data Exploration
# You must use Python to perform the analysis and generate the graphs.

# %% [markdown]
# <b>Carefully inspect and clean the data. Use simple descriptive statistics and basic univariate plots. Report your findings and how you resolved any potential issues.</b>

# %%
result = %sql SELECT * FROM customers;
original_df = result.DataFrame()
# Out:
#  * sqlite:///Bank_post.sqlite
# Done.

# %%
original_df.head()
# Out:
#    Age  Experience  Income             BranchAddress Branch Manager  Family  \
# 0   50          24      11     8536 Country Club Dr.          Derek       4
# 1   31           7     173         742 Bridle Street         Joonki       1
# 2   41          16      10     9091 S. Bowman Street         Fraser       2
# 3   53          27      44  9834 East Pineknoll Ave.          Rahul       4
# 4   29           5      33             69 Spruce Dr.       Mostapha       1
#
#   CCAvg Mortgage  PersonalLoan  Brokerage Account  ...       AdvisorName  \
# 0   0.6        0             0                  0  ...    Tanya Johansen
# 1     6        0             0                  0  ...       Brandon Sum
# 2   0.3        0             0                  0  ...  Kathaleen Horgan
# 3   1.5        0             0                  0  ...       Brandon Sum
# 4   1.8       78             0                  0  ...   Kirsten Mitchem
#
#    Advisor Designation          Branch Address 1 Branch Manager 1  \
# 0                  CFP     8536 Country Club Dr.            Derek
# 1                  CFP  9834 East Pineknoll Ave.            Rahul
# 2                  PFP     9091 S. Bowman Street           Fraser
# 3                  CFP  9834 East Pineknoll Ave.            Rahul
# 4                  PFP             69 Spruce Dr.         Mostapha
#
#             Branch Address 2 Branch Manager 2      Branch Address 3  \
# 0        234 Blue Spring Rd.              Ana  533 Hillcrest Street
# 1          742 Bridle Street           Joonki    544 Edgewood Drive
# 2  8378 West Magnolia Street         Rajarshi        518 Selby Ave.
# 3          742 Bridle Street           Joonki    544 Edgewood Drive
# 4           92 Ridgewood Dr.             Mark      8376 Euclid Lane
#
#   Branch Manager 3 Branch Address 4 Branch Manager 4
# 0            Ankur             None             None
# 1            Filip             None             None
# 2           Xavier             None             None
# 3            Filip             None             None
# 4          Jessica             None             None
#
# [5 rows x 23 columns]

# %%
original_df.dtypes
# Out:
# Age                     int64
# Experience              int64
# Income                  int64
# BranchAddress          object
# Branch Manager         object
# Family                  int64
# CCAvg                  object
# Mortgage               object
# PersonalLoan            int64
# Brokerage Account       int64
# GIC Account             int64
# Online                  int64
# CreditCard              int64
# AdvisorName            object
# Advisor Designation    object
# Branch Address 1       object
# Branch Manager 1       object
# Branch Address 2       object
# Branch Manager 2       object
# Branch Address 3       object
# Branch Manager 3       object
# Branch Address 4       object
# Branch Manager 4       object
# dtype: object

# %%
original_df.describe()
# Out:
#                Age   Experience       Income       Family  PersonalLoan  \
# count  4499.000000  4499.000000  4499.000000  4499.000000   4499.000000
# mean     45.268282    20.028895    74.303401     2.398088      0.106690
# std      11.454680    11.461481    46.310561     1.147040      0.308754
# min      23.000000    -3.000000     8.000000     1.000000      0.000000
# 25%      35.000000    10.000000    39.000000     1.000000      0.000000
# 50%      45.000000    20.000000    64.000000     2.000000      0.000000
# 75%      55.000000    30.000000    99.000000     3.000000      0.000000
# max      67.000000    43.000000   224.000000     4.000000      1.000000
#
#        Brokerage Account  GIC Account       Online   CreditCard
# count        4499.000000  4499.000000  4499.000000  4499.000000
# mean            0.108691     0.064903     0.592132     0.296733
# std             0.311286     0.246383     0.491493     0.456868
# min             0.000000     0.000000     0.000000     0.000000
# 25%             0.000000     0.000000     0.000000     0.000000
# 50%             0.000000     0.000000     1.000000     0.000000
# 75%             0.000000     0.000000     1.000000     1.000000
# max             1.000000     1.000000     1.000000     1.000000

# %%
# Cleaning CCAVG

# %%
df = original_df.copy()

# %%
#Changing names
new_column_names = ['age','experience',    
'income',    
'branch_address',    
'branch_manager',    
'family',    
'ccavg',    
'mortgage',    
'personal_loan',    
'brokerage_account',    
'gic',    
'online',    
'credit_card',    
'advisor_name',    
'advisor_designation',    
'branch_address1',    
'branch_manager1',    
'branch_address2',    
'branch_manager2',    
'branch_address3',    
'branch_manager3',    
'branch_address4',    
'branch_manager4', ]
df.columns = new_column_names

# %%
df.dtypes
# Out:
# age                     int64
# experience              int64
# income                  int64
# branch_address         object
# branch_manager         object
# family                  int64
# ccavg                  object
# mortgage               object
# personal_loan           int64
# brokerage_account       int64
# gic                     int64
# online                  int64
# credit_card             int64
# advisor_name           object
# advisor_designation    object
# branch_address1        object
# branch_manager1        object
# branch_address2        object
# branch_manager2        object
# branch_address3        object
# branch_manager3        object
# branch_address4        object
# branch_manager4        object
# dtype: object

# %%
df['ccavg'].unique()
# Out:
# array(['0.6', '6', '0.3', '1.5', '1.8', '3.4', '1.7', '0.2', '1.1', '2.8',
#        '4.1', '4.7', '3', '1.9', '0.8', '0.4', '1', '2.1', '2.6', '6.9',
#        '2.3', '1.6', '4.9', '0.1', '0', '2.5', '2', '1.666666667', '2.9',
#        '4.4', '5.7', '7.3', '8.6', '3.6', '6.6', '2.2', '4.3', '3.9',
#        '5.5', '1.4', '0.5', '6.1', '2.7', '6.666666667', '6.7',
#        '1.333333333', '5.1', '0.9', '3.8', '3.3', '3.1', '6.8', '0.7',
#        '2.666666667', '1.2', '1.3', '2.4', '8', '6.3', '3.2', '4.5',
#        '1.75', '7', '7.9', '5.3', '8.8', '4', '5.2', '3.7', '4.6', '6.5',
#        '0.75', '9', '4.2', '7.2', '0.666666667', '7.8', '5.4', '7.5',
#        '5.8', '4.75', '3.5', '7.4', '7.6', '2.333333333', '5.6',
#        '4.333333333', '8.1', '4.666666667', '5', '5.9', '4.8',
#        '5.333333333', '10', '5.666666667', '6.333333333', '8.5',
#        '3.333333333', '8.2', '8.9', '8.3', '6.4', '4.25', '3.666666667',
#        '3.25', '6.2', '2,00', '2.75', '9.3'], dtype=object)

# %%
# As seen, some values have comas indicating thousands. We will assume that 2,00 represents 2,000

# %%
df[['ccavg']] = df['ccavg'].str.replace(',', '.')
#df['ccavg'].unique()

# %%
df[['ccavg']] = pd.to_numeric(df['ccavg'])
df['ccavg'].unique()
# Out:
# array([ 0.6       ,  6.        ,  0.3       ,  1.5       ,  1.8       ,
#         3.4       ,  1.7       ,  0.2       ,  1.1       ,  2.8       ,
#         4.1       ,  4.7       ,  3.        ,  1.9       ,  0.8       ,
#         0.4       ,  1.        ,  2.1       ,  2.6       ,  6.9       ,
#         2.3       ,  1.6       ,  4.9       ,  0.1       ,  0.        ,
#         2.5       ,  2.        ,  1.66666667,  2.9       ,  4.4       ,
#         5.7       ,  7.3       ,  8.6       ,  3.6       ,  6.6       ,
#         2.2       ,  4.3       ,  3.9       ,  5.5       ,  1.4       ,
#         0.5       ,  6.1       ,  2.7       ,  6.66666667,  6.7       ,
#         1.33333333,  5.1       ,  0.9       ,  3.8       ,  3.3       ,
#         3.1       ,  6.8       ,  0.7       ,  2.66666667,  1.2       ,
#         1.3       ,  2.4       ,  8.        ,  6.3       ,  3.2       ,
#         4.5       ,  1.75      ,  7.        ,  7.9       ,  5.3       ,
#         8.8       ,  4.        ,  5.2       ,  3.7       ,  4.6       ,
#         6.5       ,  0.75      ,  9.        ,  4.2       ,  7.2       ,
#         0.66666667,  7.8       ,  5.4       ,  7.5       ,  5.8       ,
#         4.75      ,  3.5       ,  7.4       ,  7.6       ,  2.33333333,
#         5.6       ,  4.33333333,  8.1       ,  4.66666667,  5.        ,
#         5.9       ,  4.8       ,  5.33333333, 10.        ,  5.66666667,
#         6.33333333,  8.5       ,  3.33333333,  8.2       ,  8.9       ,
#         8.3       ,  6.4       ,  4.25      ,  3.66666667,  3.25      ,
#         6.2       ,  2.75      ,  9.3       ])

# %%
# Cleaning Mortgage

# %%
df['mortgage'].unique()
df[['mortgage']] = df['mortgage'].str.replace('$','')
df[['mortgage']] = pd.to_numeric(df['mortgage'])
df['mortgage'].unique()
# Out:
# array([  0,  78, 185, 118, 380, 186, 248, 148, 146, 132,  94, 175, 123,
#        345, 223,  95, 147, 263, 100, 182, 110,  96,  87, 103,  77, 105,
#         86, 102, 236, 149, 112, 329, 171, 222, 323, 174,  88, 212, 203,
#        140, 219,  83, 325, 159, 117, 328, 257, 152, 156, 366, 256, 119,
#        151, 200, 104, 342, 144, 137, 154, 355, 125, 309, 127, 120, 107,
#         99, 138, 106, 181, 109, 249, 131,  82, 143, 322, 428, 158, 167,
#        315, 122, 319, 601, 378,  81, 368, 475,  79, 136, 113, 188, 184,
#        130, 239, 179, 180, 218, 145, 292, 240, 214, 565, 190, 111, 114,
#        205, 221, 297,  91, 202, 364, 169, 271, 101, 421, 172, 213, 189,
#        238, 244, 241, 142, 294, 308, 293, 178, 230, 307, 262, 176, 164,
#        116, 577, 134, 255, 187, 129, 217, 305, 135,  98,  90, 242, 277,
#         75, 477, 193,  76,  97,  85,  93, 582, 224, 150,  92, 229, 403,
#        245, 204, 282, 246, 157, 124,  89, 331, 408, 310, 250, 357, 243,
#         80, 266, 273, 481, 162, 220, 227, 612, 547, 165, 416, 508, 115,
#         84, 314, 385, 284, 199, 296, 276, 458, 208, 381, 197, 522, 108,
#        207, 183, 524, 402, 196, 449, 166, 215, 232, 126, 412, 160, 252,
#        455, 234, 128, 153, 299, 392, 226, 253, 192, 161, 272, 341, 231,
#        141, 194, 446, 303, 617, 121, 358, 228, 383, 133, 333, 211, 170,
#        280, 442, 251, 289, 225, 191, 163, 298, 336, 361, 168, 290, 437,
#        275, 155, 427, 301, 327, 400, 216, 467, 330, 209, 452, 567, 394,
#        415, 285, 206, 258, 139, 352, 500, 410, 422, 432, 287, 429, 198,
#        553, 177, 233, 343, 334, 247, 313, 268, 374, 281, 382, 372, 587,
#        210, 195, 278, 483, 337, 396, 569, 431, 265, 359, 264, 406, 311,
#        581, 485, 306, 270, 354, 286, 304, 496, 260, 360, 353, 464, 470,
#        466, 351, 541, 391, 259, 267, 571, 295, 283, 550, 535, 201, 590,
#        389, 397, 373, 433, 589, 419, 237, 318, 235, 312, 398], dtype=int64)

# %%
# Cleaning Experience
df[['experience']] = df['experience'].abs()

# %%
df.describe()
# Out:
#                age   experience       income       family        ccavg  \
# count  4499.000000  4499.000000  4499.000000  4499.000000  4499.000000
# mean     45.268282    20.056457    74.303401     2.398088     1.951830
# std      11.454680    11.413172    46.310561     1.147040     1.756476
# min      23.000000     0.000000     8.000000     1.000000     0.000000
# 25%      35.000000    10.000000    39.000000     1.000000     0.700000
# 50%      45.000000    20.000000    64.000000     2.000000     1.600000
# 75%      55.000000    30.000000    99.000000     3.000000     2.600000
# max      67.000000    43.000000   224.000000     4.000000    10.000000
#
#           mortgage  personal_loan  brokerage_account          gic  \
# count  4499.000000    4499.000000        4499.000000  4499.000000
# mean     56.085575       0.106690           0.108691     0.064903
# std     101.788264       0.308754           0.311286     0.246383
# min       0.000000       0.000000           0.000000     0.000000
# 25%       0.000000       0.000000           0.000000     0.000000
# 50%       0.000000       0.000000           0.000000     0.000000
# 75%      99.500000       0.000000           0.000000     0.000000
# max     617.000000       1.000000           1.000000     1.000000
#
#             online  credit_card
# count  4499.000000  4499.000000
# mean      0.592132     0.296733
# std       0.491493     0.456868
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       1.000000     0.000000
# 75%       1.000000     1.000000
# max       1.000000     1.000000

# %%
# Checking for unique on dummy vars
df['personal_loan'].unique() 
#etc...
# Out:
# array([0, 1], dtype=int64)

# %%
df.dtypes
# Out:
# age                      int64
# experience               int64
# income                   int64
# branch_address          object
# branch_manager          object
# family                   int64
# ccavg                  float64
# mortgage                 int64
# personal_loan            int64
# brokerage_account        int64
# gic                      int64
# online                   int64
# credit_card              int64
# advisor_name            object
# advisor_designation     object
# branch_address1         object
# branch_manager1         object
# branch_address2         object
# branch_manager2         object
# branch_address3         object
# branch_manager3         object
# branch_address4         object
# branch_manager4         object
# dtype: object

# %%
# Sanitizing Strings, without designation
string_columns = ['branch_address', 'branch_manager','advisor_name','branch_address1', 'branch_manager1', 'branch_address2','branch_manager2', 'branch_address3', 'branch_manager3','branch_address4', 'branch_manager4']
#string_columns
#df.columns
df[string_columns] = df[string_columns].astype(str)
df[string_columns] = df[string_columns].apply(lambda x: x.str.title())
df[string_columns]
# Out:
#                 branch_address branch_manager       advisor_name  \
# 0        8536 Country Club Dr.          Derek     Tanya Johansen
# 1            742 Bridle Street         Joonki        Brandon Sum
# 2        9091 S. Bowman Street         Fraser   Kathaleen Horgan
# 3     9834 East Pineknoll Ave.          Rahul        Brandon Sum
# 4                69 Spruce Dr.       Mostapha    Kirsten Mitchem
# ...                        ...            ...                ...
# 4494         14 Lakeshore Lane           Yuqi        Val Sauceda
# 4495           667 E. Hall St.            Van  Eulah Kicklighter
# 4496       8017 Homestead Ave.         Bhavya        Margret Lan
# 4497    8722 Richardson Street           Oleg        Cyril Murry
# 4498     8536 Country Club Dr.          Derek       Gala Mackson
#
#                branch_address1 branch_manager1            branch_address2  \
# 0        8536 Country Club Dr.           Derek        234 Blue Spring Rd.
# 1     9834 East Pineknoll Ave.           Rahul          742 Bridle Street
# 2        9091 S. Bowman Street          Fraser  8378 West Magnolia Street
# 3     9834 East Pineknoll Ave.           Rahul          742 Bridle Street
# 4                69 Spruce Dr.        Mostapha           92 Ridgewood Dr.
# ...                        ...             ...                        ...
# 4494         14 Lakeshore Lane            Yuqi       890 W. Brickyard Dr.
# 4495           667 E. Hall St.             Van             68 Sunbeam St.
# 4496       8017 Homestead Ave.          Bhavya        387 West Fifth Ave.
# 4497    8722 Richardson Street            Oleg               5 Maple Lane
# 4498     8536 Country Club Dr.           Derek        234 Blue Spring Rd.
#
#      branch_manager2        branch_address3 branch_manager3 branch_address4  \
# 0                Ana   533 Hillcrest Street           Ankur             Nan
# 1             Joonki     544 Edgewood Drive           Filip             Nan
# 2           Rajarshi         518 Selby Ave.          Xavier             Nan
# 3             Joonki     544 Edgewood Drive           Filip             Nan
# 4               Mark       8376 Euclid Lane         Jessica             Nan
# ...              ...                    ...             ...             ...
# 4494          Huimin                                                    Nan
# 4495           Vitor    7330 West Grand St.           Utsav             Nan
# 4496            Zhuo  8536 Country Club Dr.           Derek             Nan
# 4497          Congyi        24 Trusel Court         Timothy             Nan
# 4498             Ana   533 Hillcrest Street           Ankur             Nan
#
#      branch_manager4
# 0                Nan
# 1                Nan
# 2                Nan
# 3                Nan
# 4                Nan
# ...              ...
# 4494             Nan
# 4495             Nan
# 4496             Nan
# 4497             Nan
# 4498             Nan
#
# [4499 rows x 11 columns]

# %%
df.dtypes
# Out:
# age                      int64
# experience               int64
# income                   int64
# branch_address          object
# branch_manager          object
# family                   int64
# ccavg                  float64
# mortgage                 int64
# personal_loan            int64
# brokerage_account        int64
# gic                      int64
# online                   int64
# credit_card              int64
# advisor_name            object
# advisor_designation     object
# branch_address1         object
# branch_manager1         object
# branch_address2         object
# branch_manager2         object
# branch_address3         object
# branch_manager3         object
# branch_address4         object
# branch_manager4         object
# dtype: object

# %%
#df.head()
df.describe()
# Out:
#                age   experience       income       family        ccavg  \
# count  4499.000000  4499.000000  4499.000000  4499.000000  4499.000000
# mean     45.268282    20.056457    74.303401     2.398088     1.951830
# std      11.454680    11.413172    46.310561     1.147040     1.756476
# min      23.000000     0.000000     8.000000     1.000000     0.000000
# 25%      35.000000    10.000000    39.000000     1.000000     0.700000
# 50%      45.000000    20.000000    64.000000     2.000000     1.600000
# 75%      55.000000    30.000000    99.000000     3.000000     2.600000
# max      67.000000    43.000000   224.000000     4.000000    10.000000
#
#           mortgage  personal_loan  brokerage_account          gic  \
# count  4499.000000    4499.000000        4499.000000  4499.000000
# mean     56.085575       0.106690           0.108691     0.064903
# std     101.788264       0.308754           0.311286     0.246383
# min       0.000000       0.000000           0.000000     0.000000
# 25%       0.000000       0.000000           0.000000     0.000000
# 50%       0.000000       0.000000           0.000000     0.000000
# 75%      99.500000       0.000000           0.000000     0.000000
# max     617.000000       1.000000           1.000000     1.000000
#
#             online  credit_card
# count  4499.000000  4499.000000
# mean      0.592132     0.296733
# std       0.491493     0.456868
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       1.000000     0.000000
# 75%       1.000000     1.000000
# max       1.000000     1.000000

# %%
#Examples of univariate plots
plt.boxplot(df['age'])
plt.title("Age Boxplot")
plt.ylabel("Age in years")
plt.xlabel("Values")
# Out:
# Text(0.5, 0, 'Values')

# %%
plt.hist(df['income'])
plt.title("Customers' Income")
plt.ylabel("Customers")
plt.xlabel("Income in $000")
# Out:
# Text(0.5, 0, 'Income in $000')

# %%
df_online = pd.DataFrame(df.groupby('online').size())
df_online.rename(index={0:'No',1:'Yes'}, inplace=True)

ax = df_online.plot(kind='bar')
plt.show
plt.title("Customers Who Have Banked Online")
plt.ylabel("Customers")
plt.xlabel("Has Banked Online")
# Out:
# Text(0.5, 0, 'Has Banked Online')

# %% [markdown]
# ## C)	(8 points) Exploratory Data Analysis
# You must use Python to perform the analysis and generate the graphs. </b>

# %% [markdown]
# The bank's main goal is to conver lenders into borrowers. For that, most of the analysis should be conducted trying to identify the differences between lenders and borrowers

# %%
# Examples of analysis

# %%
has_loan = df['personal_loan'] != 0
df_loan_gic = pd.DataFrame(df.groupby(['personal_loan', 'gic']).size())
df_loan_gic
# Out:
#                       0
# personal_loan gic
# 0             0    3867
#               1     152
# 1             0     340
#               1     140

# %%
df_loan = pd.DataFrame(df.groupby('personal_loan').size())
df_loan.rename(index={0:'No',1:'Yes'}, inplace=True)

ax = df_loan.plot(kind='bar')
plt.show
plt.title("Customers Who Accepted Last Campaign")
plt.ylabel("Customers")
plt.xlabel("Has Banked Online")
# Out:
# Text(0.5, 0, 'Has Banked Online')

# %%
df_hasloan  = df[(df.personal_loan != 0)]
df_hasnotloan  = df[(df.personal_loan == 0)]

# %%
ax = plt.boxplot([df_hasloan['age'], df_hasnotloan['age']], labels=['Succesful','Not Succesful'])
plt.title("Customer age by campaign success")
# Out:
# Text(0.5, 1.0, 'Customer age by campaign success')

# %%
ax = plt.boxplot([df_hasloan['income'], df_hasnotloan['income']], labels=['Succesful','Not Succesful'])
plt.title("Customer Income  by campaign success")
plt.ylabel("Income $ 000")
# Out:
# Text(0, 0.5, 'Income $ 000')

# %%
ax1 = df_hasloan['income'].plot(kind='density', sharex=False)
ax2 = df_hasnotloan['income'].plot(kind='density', sharex=False)
plt.title("Customers' Income Distribution")
plt.xlabel("Income $000")
plt.legend(labels=['Yes','No'],title = 'Accepted Campaign',loc='center left', bbox_to_anchor=(1, 0.5))

# %%
ax = plt.boxplot([df_hasloan['ccavg'], df_hasnotloan['ccavg']], labels=['Succesful','Not Succesful'])
plt.title("Customer CC average by campaign success")
plt.ylabel("Credit Card Average $ 000")
# Out:
# Text(0, 0.5, 'Credit Card Average $ 000')

# %%
# There's seem to be a correlation between income and having accepted the campaign. This makes economical sense, as bigger incomes may wish to borrow money for specific projects....

# %% [markdown]
# # D)	(10 points) Business Analytics
# You must use Python to perform the analysis and generate the graphs.
# Who is or are the most successful financial advisor(s)? Discuss your results.
# Hint: How could “successful” be defined? There might be multiple possible definitions.

# %%
# Examples of analysis:
# Defined succesful by having the biggest incomes or number of customers
# Define sucessful by versatility: working with a large range of customers and branches
# Define succesful by converting clients with the campaign

# %%
df_d = pd.DataFrame(df.groupby(['personal_loan', 'advisor_name']).size())
#df_d.columns = ['personal_loan','advisor_name','num_customers']
df_d
df_d = df_d.unstack(level=0)
df_d.columns=['noloan','loan']
df_d
df_d['total_customers'] = df_d['noloan'] +df_d['loan']
df_d['conversion_rate'] = round((df_d['loan'] / df_d['total_customers']),3)
df_d.sort_values('conversion_rate', ascending=False)
# Out:
#                     noloan  loan  total_customers  conversion_rate
# advisor_name
# Jodie Izquierdo         73    15               88            0.170
# Gita Pinelli            72    14               86            0.163
# Siobhan Flaugher        60    11               71            0.155
# Kirsten Mitchem         68    12               80            0.150
# Pansy Diblasi           74    13               87            0.149
# Zofia Rambo             92    16              108            0.148
# Val Sauceda             66    11               77            0.143
# Jacqueline Leveque      84    14               98            0.143
# Estefana Dungan         93    14              107            0.131
# Pete Dickens            73    11               84            0.131
# Marylee Bristow         73    11               84            0.131
# Ying Michaelson         67    10               77            0.130
# Kathaleen Horgan        87    13              100            0.130
# Margret Lan             74    11               85            0.129
# Eulah Kicklighter       89    13              102            0.127
# Donetta Mallet          77    11               88            0.125
# Kristle Hanby           88    12              100            0.120
# Brandon Sum             74    10               84            0.119
# Beatriz Rolf            90    12              102            0.118
# Thao Lovato             83    11               94            0.117
# Bernarda Guilliams      77    10               87            0.115
# Berry Gartman           78    10               88            0.114
# Elicia Schuyler         97    12              109            0.110
# Latrisha Barden         94    11              105            0.105
# Carylon Race            85    10               95            0.105
# Zandra Venne            85    10               95            0.105
# Ross Seipel             87    10               97            0.103
# Cecil Caves             71     8               79            0.101
# Corazon Eastin         107    12              119            0.101
# Zetta Gephart           74     8               82            0.098
# Cyndy Calcagno          96    10              106            0.094
# Jaquelyn Cubbage        88     9               97            0.093
# Weston Jeon             89     9               98            0.092
# Deedra Halderman        89     9               98            0.092
# Cyril Murry             73     7               80            0.088
# Erik Clinard            83     8               91            0.088
# Marcelene Thomson       75     7               82            0.085
# Carolin Whitmire        91     8               99            0.081
# Mariana Ghent           79     7               86            0.081
# Taylor Kemp             71     6               77            0.078
# Collene Dubon           86     7               93            0.075
# Twila Bare              75     6               81            0.074
# Gala Mackson            92     7               99            0.071
# Myesha Bromley          81     6               87            0.069
# Prudence Masters        87     6               93            0.065
# Vicki Sowers            58     4               62            0.065
# Caitlin Wimmer         106     7              113            0.062
# Aleida Suitt            94     6              100            0.060
# Tanya Johansen          94     5               99            0.051

# %%
df_chart = pd.DataFrame(df_d.sort_values('conversion_rate', ascending=True))
fig= plt.figure(figsize=(8,20))
plt.barh(df_chart.index,round(100*(df_chart['conversion_rate']),3))
plt.title("Advisors' Loan Conversion Rate")
plt.xlabel("Conversion Rate in %")
plt.ylabel("Advisor name")

#labels = df_chart['conversion_rate'].tolist()

for x, y in zip((round(100*(df_chart['conversion_rate']),3)),df_chart.index):
    #label = '{0:.1%}'.format(x)
    plt.annotate(x, (x,y))
