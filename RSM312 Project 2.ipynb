# %%
import pandas as pd
import numpy as np

# %%
df_2015 = pd.read_csv("Analytics_mindset_case_studies_PCard_FY2015.csv", encoding = 'ISO-8859-1', parse_dates = ['Transaction Date', 'Posted Date'])

# %%
df_2014 = pd.read_csv("Analytics_mindset_case_studies_PCard_FY2014.csv", encoding = 'ISO-8859-1', parse_dates = ['Transaction Date', 'Posted Date'])

# %%
df_2015.head()
# Out:
#    Agency Number                Agency Name Cardholder Last Name  \
# 0           1000  OKLAHOMA STATE UNIVERSITY                Clark
# 1           1000  OKLAHOMA STATE UNIVERSITY                Clark
# 2           1000  OKLAHOMA STATE UNIVERSITY                Clark
# 3           1000  OKLAHOMA STATE UNIVERSITY                Clark
# 4           1000  OKLAHOMA STATE UNIVERSITY                Clark
#
#   Cardholder First Initial                                        Description  \
# 0                        K                                   GENERAL PURCHASE
# 1                        M                                   GENERAL PURCHASE
# 2                        M                              NEWS ADV./SUBSC. EACH
# 3                        M                                   GENERAL PURCHASE
# 4                        P  BH 3-INX7-IN SMALL BRASS B PCS|BLUE HAWK SHOE ...
#
#        Amount                  Vendor Transaction Date Posted Date  \
# ...

# %%
df_2014.head()
# Out:
#    Agency Number                Agency Name Cardholder Last Name  \
# 0           1000  OKLAHOMA STATE UNIVERSITY                Mason
# 1           1000  OKLAHOMA STATE UNIVERSITY                Mason
# 2           1000  OKLAHOMA STATE UNIVERSITY               Massey
# 3           1000  OKLAHOMA STATE UNIVERSITY               Massey
# 4           1000  OKLAHOMA STATE UNIVERSITY        Mauro-Herrera
#
#   Cardholder First Initial                   Description  Amount  \
# 0                        C              GENERAL PURCHASE  890.00
# 1                        C                  ROOM CHARGES  368.96
# 2                        J              GENERAL PURCHASE  165.82
# 3                        T              GENERAL PURCHASE   96.39
# 4                        M  HAMMERMILL COPY PLUS COPY EA  125.96
#
#            Vendor Transaction Date Posted Date  \
# 0           NACAS       2013-07-30  2013-07-31
# 1  SHERATON HOTEL       2013-07-30  2013-07-31
# ...

# %%
df_2014.dtypes
# Out:
# Agency Number                            int64
# Agency Name                             object
# Cardholder Last Name                    object
# Cardholder First Initial                object
# Description                             object
# Amount                                 float64
# Vendor                                  object
# Transaction Date                datetime64[ns]
# Posted Date                     datetime64[ns]
# Merchant Category Code (MCC)            object
# dtype: object

# %%
df_2015.dtypes
# Out:
# Agency Number                            int64
# Agency Name                             object
# Cardholder Last Name                    object
# Cardholder First Initial                object
# Description                             object
# Amount                                  object
# Vendor                                  object
# Transaction Date                datetime64[ns]
# Posted Date                     datetime64[ns]
# Merchant Category Code (MCC)            object
# dtype: object

# %%
df_2015.columns
# Out:
# Index(['Agency Number', 'Agency Name', 'Cardholder Last Name',
#        'Cardholder First Initial', 'Description', 'Amount', 'Vendor',
#        'Transaction Date', 'Posted Date', 'Merchant Category Code (MCC)'],
#       dtype='object')

# %%
type(df_2015.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
c = [1, 2, 3]
len(c)
# Out:
# 3

# %%
df_2015.columns = df_2015.columns.str.strip()

# %%
df_2014.columns = df_2014.columns.str.strip()

# %%
df_2015.rename(columns = {'Agency Number': 'AgencyNumber', 'Agency Name': 'AgencyName', 'Cardholder Last Name': 'CardholderLastName',
                          'Cardholder First Initial': 'CardholderFirstInitial', 'Transaction Date': 'TransactionDate', 'Posted Date': 'PostedDate', 
                          'Merchant Category Code (MCC)': 'MCC'
                         }, inplace = True)

# %%
df_2014.rename(columns = {'Agency Number': 'AgencyNumber', 'Agency Name': 'AgencyName', 'Cardholder Last Name': 'CardholderLastName',
                          'Cardholder First Initial': 'CardholderFirstInitial', 'Transaction Date': 'TransactionDate', 'Posted Date': 'PostedDate', 
                          'Merchant Category Code (MCC)': 'MCC'
                         }, inplace = True)

# %%
df_2015['Amount']= df_2015['Amount'].str.replace('$', '').str.replace(',', '')
# Out:
# C:\Users\xomai\AppData\Local\Temp/ipykernel_24164/2749733093.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_2015['Amount']= df_2015['Amount'].str.replace('$', '').str.replace(',', '')

# %%
df_2015
# Out:
#         AgencyNumber                 AgencyName CardholderLastName  \
# 0               1000  OKLAHOMA STATE UNIVERSITY              Clark
# 1               1000  OKLAHOMA STATE UNIVERSITY              Clark
# 2               1000  OKLAHOMA STATE UNIVERSITY              Clark
# 3               1000  OKLAHOMA STATE UNIVERSITY              Clark
# 4               1000  OKLAHOMA STATE UNIVERSITY              Clark
# ...              ...                        ...                ...
# 437574         98000      GRAND RIVER DAM AUTH.            Wheeler
# 437575         98000      GRAND RIVER DAM AUTH.            Wheeler
# 437576         98000      GRAND RIVER DAM AUTH.            Wheeler
# 437577         98000      GRAND RIVER DAM AUTH.         Cardholder
# 437578         98000      GRAND RIVER DAM AUTH.             Bailey
#
#        CardholderFirstInitial  \
# 0                           K
# 1                           M
# 2                           M
# 3                           M
# ...

# %%
df_2015['Amount']= df_2015['Amount'].str.replace('(', '-', regex = True)
df_2015['Amount']= df_2015['Amount'].str.replace(')', '', regex = True)

# %%
df_2015['Amount'] = df_2015['Amount'].astype(float)

# %%
df_2014['Amount'] = df_2014['Amount'].astype(float)

# %%
df_2014
# Out:
#         AgencyNumber                 AgencyName CardholderLastName  \
# 0               1000  OKLAHOMA STATE UNIVERSITY              Mason
# 1               1000  OKLAHOMA STATE UNIVERSITY              Mason
# 2               1000  OKLAHOMA STATE UNIVERSITY             Massey
# 3               1000  OKLAHOMA STATE UNIVERSITY             Massey
# 4               1000  OKLAHOMA STATE UNIVERSITY      Mauro-Herrera
# ...              ...                        ...                ...
# 442453         98000      GRAND RIVER DAM AUTH.         Cardholder
# 442454         98000      GRAND RIVER DAM AUTH.         Cardholder
# 442455         98000      GRAND RIVER DAM AUTH.         Cardholder
# 442456         98000      GRAND RIVER DAM AUTH.         Cardholder
# 442457         98000      GRAND RIVER DAM AUTH.         Cardholder
#
#        CardholderFirstInitial                   Description    Amount  \
# 0                           C              GENERAL PURCHASE    890.00
# ...

# %%
df_2015['CardholderFirstInitial']=df_2015['CardholderFirstInitial'].str.upper()

# %%
df_2014['CardholderFirstInitial']=df_2014['CardholderFirstInitial'].str.upper()

# %%
dataset = pd.concat([df_2014, df_2015])

# %%
dataset.head()
# Out:
#    AgencyNumber                 AgencyName CardholderLastName  \
# 0          1000  OKLAHOMA STATE UNIVERSITY              Mason
# 1          1000  OKLAHOMA STATE UNIVERSITY              Mason
# 2          1000  OKLAHOMA STATE UNIVERSITY             Massey
# 3          1000  OKLAHOMA STATE UNIVERSITY             Massey
# 4          1000  OKLAHOMA STATE UNIVERSITY      Mauro-Herrera
#
#   CardholderFirstInitial                   Description  Amount  \
# 0                      C              GENERAL PURCHASE  890.00
# 1                      C                  ROOM CHARGES  368.96
# 2                      J              GENERAL PURCHASE  165.82
# 3                      T              GENERAL PURCHASE   96.39
# 4                      M  HAMMERMILL COPY PLUS COPY EA  125.96
#
#            Vendor TransactionDate PostedDate  \
# 0           NACAS      2013-07-30 2013-07-31
# 1  SHERATON HOTEL      2013-07-30 2013-07-31
# 2  SEARS.COM 9300      2013-07-29 2013-07-31
# ...
